# %%
pip install torch torchvision transformers accelerate datasets peft bitsandbytes trl==0.15.2 triton cut_cross_entropy unsloth_zoo sentencepiece huggingface_hub hf_transfer
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Collecting datasets
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: peft in /usr/local/lib/python3.11/dist-packages (0.15.2)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# Collecting trl==0.15.2
#   Downloading trl-0.15.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: triton in /usr/local/lib/python3.11/dist-packages (3.2.0)
# Collecting cut_cross_entropy
#   Downloading cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting unsloth_zoo
#   Downloading unsloth_zoo-2025.4.4-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (0.2.0)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (0.30.2)
# Collecting hf_transfer
#   Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl==0.15.2) (13.9.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.2.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec (from torch)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting tyro (from unsloth_zoo)
#   Downloading tyro-0.9.20-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo) (0.45.1)
# Collecting protobuf<4.0.0 (from unsloth_zoo)
#   Downloading protobuf-3.20.3-py2.py3-none-any.whl.metadata (720 bytes)
# Collecting msgspec (from unsloth_zoo)
#   Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Collecting hf-xet>=0.1.4 (from huggingface_hub[hf_xet]>=0.30.0->unsloth_zoo)
#   Downloading hf_xet-1.1.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (494 bytes)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl==0.15.2) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl==0.15.2) (2.19.1)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth_zoo) (0.16)
# Collecting shtab>=1.5.6 (from tyro->unsloth_zoo)
#   Downloading shtab-1.7.2-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth_zoo) (4.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl==0.15.2) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading trl-0.15.2-py3-none-any.whl (318 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.9/318.9 kB 23.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 102.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 87.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.1 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 12.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 106.6 MB/s eta 0:00:00
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 39.6 MB/s eta 0:00:00
# Downloading bitsandbytes-0.45.5-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 27.5 MB/s eta 0:00:00
# Downloading cut_cross_entropy-25.1.1-py3-none-any.whl (22 kB)
# Downloading unsloth_zoo-2025.4.4-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 kB 15.1 MB/s eta 0:00:00
# Downloading hf_transfer-0.1.9-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 114.4 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 13.1 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 24.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 18.5 MB/s eta 0:00:00
# Downloading protobuf-3.20.3-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 20.1 MB/s eta 0:00:00
# Downloading msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 24.5 MB/s eta 0:00:00
# Downloading tyro-0.9.20-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 kB 14.3 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 22.1 MB/s eta 0:00:00
# Downloading hf_xet-1.1.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 MB 46.6 MB/s eta 0:00:00
# Downloading shtab-1.7.2-py3-none-any.whl (14 kB)
# Installing collected packages: xxhash, shtab, protobuf, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, msgspec, hf-xet, hf_transfer, fsspec, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, tyro, nvidia-cusolver-cu12, datasets, cut_cross_entropy, bitsandbytes, trl, unsloth_zoo
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.17.1 requires protobuf<6.0.0,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# Successfully installed bitsandbytes-0.45.5 cut_cross_entropy-25.1.1 datasets-3.6.0 dill-0.3.8 fsspec-2025.3.0 hf-xet-1.1.0 hf_transfer-0.1.9 msgspec-0.19.0 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 protobuf-3.20.3 shtab-1.7.2 trl-0.15.2 tyro-0.9.20 unsloth_zoo-2025.4.4 xxhash-3.5.0

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/CS685 Final/")
print(os.listdir())
# Out:
# ['sft_data_train.jsonl', 'sft_data_test.jsonl']

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, Trainer, TrainingArguments, DataCollatorForLanguageModeling
from peft import prepare_model_for_kbit_training, LoraConfig, get_peft_model
from datasets import load_dataset
import json

# %%
# 4‑bit quantization config
quant_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.bfloat16,
)

model = AutoModelForCausalLM.from_pretrained(
    "NickyNicky/experimental-Mistral-1b-V00",
    quantization_config=quant_config,
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained("NickyNicky/experimental-Mistral-1b-V00", padding_side="left")

# Fixes value error saying that there is no padding token
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/568 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/3.48G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.48G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/115 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.74k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/90.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/189 [00:00<?, ?B/s]

# %%
from peft import prepare_model_for_kbit_training, LoraConfig, get_peft_model

# Preprocess for k‑bit training
model = prepare_model_for_kbit_training(model)

# LoRA adapter config
lora_config = LoraConfig(
    r=16,
    lora_alpha=8,
    target_modules="all-linear",
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM"
)
# Wrap model with LoRA adapters
model = get_peft_model(model, lora_config)

# %%
from datasets import load_dataset
from transformers import AutoTokenizer


SYSTEM_PROMPT = ("[INST] You are a board-certified physician. Answer the following multiple choice question: \n")

# 1. Load raw JSONL
ds = load_dataset("json", data_files={"train":"sft_data_train.jsonl","test":"sft_data_test.jsonl"})

# Saving 10 percent for eval dataset
split_ds = ds["train"].train_test_split(test_size=0.1, seed=42)
train_set = split_ds["train"]
eval_set  = split_ds["test"]

def format_example(ex):
    prompt  = SYSTEM_PROMPT + ex["prompt"] + "[/INST]"
    answer  = f"Answer: {ex['response']}"
    return prompt + "\n" + answer

def preprocess(batch):
    # build prompt+eos and response+eos
    prompts   = [SYSTEM_PROMPT + p + "[/INST]" + tokenizer.eos_token for p in batch["prompt"]]
    responses = ["Answer: " + r + tokenizer.eos_token for r in batch["response"]]

    enc_p = tokenizer(prompts,   truncation=True, max_length=1024, padding=False)
    enc_r = tokenizer(responses, truncation=True, max_length=128,  padding=False)

    input_ids, attention_mask, labels = [], [], []
    for p_ids, r_ids in zip(enc_p["input_ids"], enc_r["input_ids"]):
        ids = p_ids + r_ids
        input_ids.append(ids)
        attention_mask.append([1] * len(ids))
        labels.append([-100] * len(p_ids) + r_ids)   # mask prompt

    return {
        "input_ids": input_ids,
        "attention_mask": attention_mask,
        "labels": labels,
    }



"""

tokenized = {}
tokenized["train"] = train_set.map(preprocess, batched=True, remove_columns=["prompt", "response"])
tokenized["eval"] = eval_set.map(preprocess, batched=True, remove_columns=["prompt", "response"])
tokenized["test"] = ds["test"].map(preprocess, batched=True, remove_columns=["prompt", "response"])
"""
# Out:
# '\n\ntokenized = {}\ntokenized["train"] = train_set.map(preprocess, batched=True, remove_columns=["prompt", "response"])\ntokenized["eval"] = eval_set.map(preprocess, batched=True, remove_columns=["prompt", "response"])\ntokenized["test"] = ds["test"].map(preprocess, batched=True, remove_columns=["prompt", "response"])\n'

# %%
from transformers import TrainingArguments
from trl import SFTTrainer, SFTConfig

model.gradient_checkpointing_enable()

training_args = SFTConfig(
    output_dir="mistral-1b-qa-qlora2",
    per_device_train_batch_size=16,
    gradient_accumulation_steps=4,
    num_train_epochs=3,
    learning_rate=6e-4,
    lr_scheduler_type="cosine",
    warmup_ratio=0.05,
    max_grad_norm=1.0,
    logging_steps = 10,
    eval_strategy = "steps",
    eval_steps = 10,
    save_strategy = "steps",
    save_steps = 10,
    fp16=True,
    load_best_model_at_end=True,
    max_seq_length=2048,
    packing=False,

)

trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    args=training_args,
    train_dataset=train_set,
    eval_dataset=eval_set,
    formatting_func=format_example,
)

trainer.train()

# Save LoRA adapters and tokenizer
model.save_pretrained("mistral-1b-qa-qlora2")
tokenizer.save_pretrained("mistral-1b-qa-qlora2")
# Out:
# <ipython-input-21-0eb78873882d>:27: FutureWarning: `tokenizer` is deprecated and removed starting from version 0.16.0 for `SFTTrainer.__init__`. Use `processing_class` instead.
#   trainer = SFTTrainer(
# Applying formatting function to train dataset:   0%|          | 0/7916 [00:00<?, ? examples/s]
# Converting train dataset to ChatML:   0%|          | 0/7916 [00:00<?, ? examples/s]
# Applying chat template to train dataset:   0%|          | 0/7916 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/7916 [00:00<?, ? examples/s]
# Truncating train dataset:   0%|          | 0/7916 [00:00<?, ? examples/s]
# Applying formatting function to eval dataset:   0%|          | 0/880 [00:00<?, ? examples/s]
# Converting eval dataset to ChatML:   0%|          | 0/880 [00:00<?, ? examples/s]
# Applying chat template to eval dataset:   0%|          | 0/880 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/880 [00:00<?, ? examples/s]
# Truncating eval dataset:   0%|          | 0/880 [00:00<?, ? examples/s]
# No label_names provided for model class `PeftModelForCausalLM`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
#     <div>
#
#       <progress value='148' max='369' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [148/369 14:00 < 21:12, 0.17 it/s, Epoch 1.19/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>10.471100</td>
#       <td>9.508812</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>8.869300</td>
#       <td>8.350829</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>8.158700</td>
#       <td>7.925789</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>7.751500</td>
#       <td>7.531629</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>7.430000</td>
#       <td>7.309631</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>7.190800</td>
#       <td>6.993793</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>6.725500</td>
#       <td>6.448228</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>6.298600</td>
#       <td>6.130108</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>5.984700</td>
#       <td>5.881272</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>5.813200</td>
#       <td>5.694041</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>5.644600</td>
#       <td>5.551842</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>5.482700</td>
#       <td>5.440650</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>5.400300</td>
#       <td>5.328484</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>5.277100</td>
#       <td>5.246284</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
def collate_prompt(batch):
    """Take tokenized examples (with labels) → batched PROMPT ids/masks
       plus raw answer+explanation ids for later PPL."""
    prompt_ids, prompt_masks = [], []
    ans_ids, expl_ids = [], []     # store for later perplexity

    for ex in batch:
        ids   = ex["input_ids"]
        lbl   = ex["labels"]

        # prompt ends just BEFORE the first non-100 label
        split = lbl.index(next(x for x in lbl if x != -100))
        # 'Answer', ':', letter  ->  we want generation to START at that letter
        prompt = ids[:split + 2]      # prompt + 'Answer:' (no letter yet)
        letter = ids[split + 2]       # gold letter token (for later PPL)
        expl   = ids[split + 3 :]     # explanation tokens

        prompt_ids.append(torch.tensor(prompt))
        prompt_masks.append(torch.ones(len(prompt), dtype=torch.long))

        ans_ids.append(torch.tensor([letter]))
        expl_ids.append(torch.tensor(expl))

    pad = lambda seqs, val: pad_sequence(seqs, batch_first=True, padding_value=val)
    return {
        "prompt_ids":   pad(prompt_ids, tokenizer.pad_token_id),
        "prompt_masks": pad(prompt_masks, 0),
        "ans_ids":      ans_ids,   # list[1-D]  keep ragged
        "expl_ids":     expl_ids,  # list[1-D]
    }

# %%
import torch, re, math
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
from tqdm.auto import tqdm
from sklearn.metrics import accuracy_score
from transformers import (AutoModelForCausalLM,
                          AutoTokenizer)

device = "cuda" if torch.cuda.is_available() else "cpu"

model_id  = "mistral-1b-qa-qlora2"
model     = AutoModelForCausalLM.from_pretrained(model_id).to(device)
tokenizer = AutoTokenizer.from_pretrained(model_id)
tokenizer.padding_side = "left"
model.eval()

EOS_ID   = tokenizer.eos_token_id
PAD_ID   = tokenizer.pad_token_id or EOS_ID

loader = DataLoader(ds["test"],
                    batch_size=12,
                    shuffle=False,
                    collate_fn=collate_prompt)

pred_letters = []   # model’s chosen A/B/C/D
gold_letters = []   # ground-truth letters
ppl_vals     = []   # per-example perplexities

for batch in loader:
  prompt_ids  = batch["prompt_ids"].to(device)
  prompt_mask = batch["prompt_masks"].to(device)

  gen_ids = model.generate(
      input_ids      = prompt_ids,
      attention_mask = prompt_mask,
      max_new_tokens = 64,
      do_sample = True,
      temperature    = 0.7,
      top_p          = 0.9,
      repetition_penalty = 1.2,
      no_repeat_ngram_size = 4,
      eos_token_id   = tokenizer.eos_token_id,
      pad_token_id   = tokenizer.eos_token_id,
  )

  # decode NEW tokens only (batched)
  new_tokens = gen_ids[:, prompt_ids.size(1):]
  pred_texts = tokenizer.batch_decode(new_tokens, skip_special_tokens=True)

  # extract letters with one regex pass each
  pred_letters_batch = [
      re.search(r"\b([A-D])(?=[\.\s])", txt).group(1)
      if re.search(r"\b([A-D])(?=[\.\s])", txt) else ""
      for txt in pred_texts
  ]
  pred_letters.extend(pred_letters_batch)

  # Build a padded tensor of ctx+expl for the whole batch
  ctx_seqs, lbl_seqs = [], []
  for prompt, gold_letter, expl in zip(prompt_ids.cpu(), batch["ans_ids"], batch["expl_ids"]):
      ctx   = torch.cat([prompt, gold_letter])         # prompt + gold letter
      inp   = torch.cat([ctx, expl])                   # full sequence
      lbl   = inp.clone()
      lbl[:ctx.size(0)] = -100                         # mask prompt+letter
      ctx_seqs.append(inp)
      lbl_seqs.append(lbl)

  max_len = max(t.numel() for t in ctx_seqs)
  pad = lambda lst, val: pad_sequence(lst, batch_first=True,
                                      padding_value=val)
  input_batch  = pad(ctx_seqs, tokenizer.pad_token_id).to(device)
  label_batch  = pad(lbl_seqs, -100).to(device)

  with torch.no_grad():
      loss = model(input_ids=input_batch, labels=label_batch).loss
      # loss is mean over unmasked tokens already
      ppl_vals.extend(torch.exp(loss).repeat(input_batch.size(0)).cpu().tolist())
# Out:
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-f0c306d51026> in <cell line: 0>()
#      31   prompt_mask = batch["prompt_masks"].to(device)
#      32
# ---> 33   gen_ids = model.generate(
#      34       input_ids      = prompt_ids,
#      35       attention_mask = prompt_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, **kwargs)
#    2463
#    2464             # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2465             result = self._sample(
#    2466                 input_ids,
#    2467                 logits_processor=prepared_logits_processor,
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3432                 is_prefill = False
#    3433             else:
# -> 3434                 outputs = model_forward(**model_inputs, return_dict=True)
#    3435
#    3436             # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     963
#     964         try:
# --> 965             output = func(self, *args, **kwargs)
#     966             if is_requested_to_return_tuple or (is_configured_to_return_tuple and is_top_level_module):
#     967                 output = output.to_tuple()
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/deprecation.py in wrapped_func(*args, **kwargs)
#     170                 warnings.warn(message, FutureWarning, stacklevel=2)
#     171
# --> 172             return func(*args, **kwargs)
#     173
#     174         return wrapped_func
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, cache_position, logits_to_keep, **kwargs)
#     808
#     809         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 810         outputs: BaseModelOutputWithPast = self.model(
#     811             input_ids=input_ids,
#     812             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/utils/generic.py in wrapper(self, *args, **kwargs)
#     963
#     964         try:
# --> 965             output = func(self, *args, **kwargs)
#     966             if is_requested_to_return_tuple or (is_configured_to_return_tuple and is_top_level_module):
#     967                 output = output.to_tuple()
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, cache_position, **flash_attn_kwargs)
#     534                 )
#     535             else:
# --> 536                 layer_outputs = decoder_layer(
#     537                     hidden_states,
#     538                     attention_mask=causal_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     247
#     248         # Self Attention
# --> 249         hidden_states, self_attn_weights = self.self_attn(
#     250             hidden_states=hidden_states,
#     251             attention_mask=attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mistral/modeling_mistral.py in forward(self, hidden_states, position_embeddings, attention_mask, past_key_value, cache_position, **kwargs)
#     163
#     164         query_states = self.q_proj(hidden_states).view(hidden_shape).transpose(1, 2)
# --> 165         key_states = self.k_proj(hidden_states).view(hidden_shape).transpose(1, 2)
#     166         value_states = self.v_proj(hidden_states).view(hidden_shape).transpose(1, 2)
#     167
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/layer.py in forward(self, x, *args, **kwargs)
#     710             result = self.base_layer(x, *args, **kwargs)
#     711         else:
# --> 712             result = self.base_layer(x, *args, **kwargs)
#     713             torch_result_dtype = result.dtype
#     714
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
import torch, re, math
from torch.utils.data import DataLoader
from torch.nn.utils.rnn import pad_sequence
from tqdm.auto import tqdm
from sklearn.metrics import accuracy_score
from transformers import (AutoModelForCausalLM,
                          AutoTokenizer)

device = "cuda" if torch.cuda.is_available() else "cpu"

model_id  = "mistral-1b-qa-qlora2"
model     = AutoModelForCausalLM.from_pretrained(model_id).to(device)
tokenizer = AutoTokenizer.from_pretrained(model_id)
model.eval()

EOS_ID   = tokenizer.eos_token_id
PAD_ID   = tokenizer.pad_token_id or EOS_ID

# Collator that pads input_ids, attention_mask, labels together

def collate_test(batch):
    ids, attn, lbl = [], [], []
    for ex in batch:
        ids .append(torch.tensor(ex["input_ids"],      dtype=torch.long))
        attn.append(torch.tensor(ex["attention_mask"], dtype=torch.long))
        lbl .append(torch.tensor(ex["labels"],         dtype=torch.long))

    maxlen = max(t.size(0) for t in ids)
    pad_   = lambda seqs, val: pad_sequence(seqs, batch_first=True, padding_value=val)

    return {
        "input_ids":      pad_(ids,  PAD_ID).to(device),
        "attention_mask": pad_(attn, 0).to(device),
        "labels":         pad_(lbl, -100).to(device)
    }

loader = DataLoader(
    tokenized["test"],         # your saved split
    batch_size=1,
    shuffle=False,
    collate_fn=collate_test
)

pred_letters, gold_letters, ppl_vals = [], [], []

for batch in tqdm(loader, desc="eval"):
    inp_ids  = batch["input_ids"]
    attn_mask= batch["attention_mask"]
    labels   = batch["labels"]

    # Determine for each example where the prompt ends
    # Boolean mask of where the answer/explanation starts
    is_answer = labels.ne(-100)
    # position of first True in each row
    first_idx = is_answer.float().argmax(dim=1)    # shape [B]

    # we generate with ONLY the prompt tokens
    max_prompt = first_idx.max().item() + 1            # longest prompt in batch
    prompt_ids   = torch.stack([
        torch.cat([row[:p+1],              # prompt + eos
                   row.new_zeros(max_prompt-p-1)])      # pad
        for row, p in zip(inp_ids, first_idx)
    ])
    prompt_mask  = (prompt_ids != 0) & (prompt_ids != PAD_ID)

    # Generate predictions
    gen = model.generate(
        input_ids = prompt_ids,
        attention_mask = prompt_mask,
        do_sample = True,
        max_new_tokens = 64,
        early_stopping = True,
        pad_token_id = EOS_ID,
        top_p = 0.92,
        top_k = 50,
        repetition_penalty = 1.5,       # discourages copying
        no_repeat_ngram_size = 4,       # hard constraint
        eos_token_id = tokenizer.eos_token_id,
    )

    # Extract predicted letter
    for g, p_len in zip(gen, first_idx):
        txt = tokenizer.decode(g[p_len+1:]).strip()
        print("Model output: " + txt)
        m   = re.search(r"\b([A-D])(?=[\.\s])", txt)
        pred_letters.append(m.group(1) if m else "")

    # Gold letter & explanation perplexity (no re‑tokenising)
    for ids, p_len in zip(inp_ids, first_idx):
        # find first *letter* token after 'Answer' ':'  (it’s the 3rd new token)
        gold_letter_tok = ids[p_len + 3]          # p_len = '▁Answer', p_len+1 = '▁:'
        gold_char = tokenizer.decode([gold_letter_tok]).strip()[0]
        gold_letters.append(gold_char)
        print("Correct answer: " + gold_char)

        # Explanation token IDs (after the answer letter)
        ctx_ids  = ids[: p_len + 3].unsqueeze(0)     # [1, C]
        expl_ids = ids[p_len + 3 :].unsqueeze(0)     # [1, E]

        # Build input and labels
        input_ids = torch.cat([ctx_ids, expl_ids], dim=1)       # [1, C+E]
        labels     = input_ids.clone()                          # copy
        labels[:, : ctx_ids.size(1)] = -100                     # mask prompt+answer
        with torch.no_grad():
            loss = model(input_ids=input_ids, labels=labels).loss
        ppl_vals.append(math.exp(loss.item()))

# ------------------------------------------------------------------
# Metrics
# ------------------------------------------------------------------
acc = accuracy_score(gold_letters, pred_letters)
ppl = sum(ppl_vals)/len(ppl_vals)

print(f"Letter accuracy : {acc*100:.2f}%")
print(f"Avg explain PPL : {ppl:.2f}")
# Out:
# eval:   0%|          | 0/1078 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/transformers/generation/configuration_utils.py:679: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# Model output: Answer: B0. Decrethrophol of a varoma due to the left ventilation from anuseum, can lead to increased by her hypotidase.<|im_end|>
# Correct answer: B
# Model output: Answer: D. Erophy
# Explanation: ThisMyчкаylilicfiniteVP-negativeyroidism, the absence of hemoglobin and increased risk of anativeic pneumonia, leading to prevent infections of gastroesia and myococcus. Hteral
# Correct answer: D
# Model output: Answer: C. A. Oing and elevated Barb
# Explanation: The presence of renal también DEFin is appropriate due to lacerb infections in the right;odies-thase likeك’s syndrome, commonly presents with her chronic leukdfelanoma or potentialstride ab
# Correct answer: B
# Model output: Answer: C. The presence for this condition, fever, where the child, erythrophadenopathycin. Intric acid or pancreat, as it is appropriate for this diagnosistextttQuick suggest anemia due to acute abdominal symptoms with impaired院 2P-
# Correct answer: D
# Model output: Answer: B. Increased malignal cystic in the patient's symptoms suggest chronic hemoglobulin, consistent with the child likely due to increased by decre роicreject-14. Intration) is associated}}_{) can cause), which aligning indicate her 119 mg
# Correct answer: B
# Model output: Answer: C. Hg.,ation. Intric anem with increased附ictosus, including an antenia by hypercal Imagecrosis, likely due to assess-lineation and elevated by the absence.
# Explanationrente disorder (e is indicated for decreased acute
# Correct answer: D
# Model output: Answer: D. Decreased in urinary
# Explanation: The patient's symptoms, including risk due to acute heart failure suggest a commonerine can lead to increased antagoninogenus, as itether opsstract (25), which increases her infections with gastrointestinal
# Correct answer: C
# Model output: Answer: C. 20
# Explanation: Oralated Australiankernelylase is effective for gastrointestinal fl YoungLOBAL obtosphate's symptoms suggest hemorrhea, as it the most commonly associated with hyperplenia due to tim pon (e and fluid) is likely
# Correct answer: C
# Model output: Answer: C. Methment of her urine on the riskia due to increasedホal bleeding syndrome suggest hypertrophoccal thermal方. The patient's severe fever with cystroheum likebourne with her symptoms. Intration) is indicated by 250), as it
# Correct answer: B
# Model output: Answer: D. Intrate and increasedomy's with pneumonia, which can lead to impairment of hemolose the right. This presence 6250), characterized by mild to evaluateic an acetylase (P and a risk rankedid syndrome, as it, including hyp
# Correct answer: A
# Model output: Answer: D. The boy likely due to increasedadem
# Explanation: This patient' Raf the condition, likely from lymphadenopathycardia suggests acute glomericfiniteosis, as it Veterigtepragma 5) suggestTree), which aligning, leading to assess disease and urinary
# Correct answer: D
# Model output: Answer: D. Crophyicarditis and elevation
# Explanation: E needle's severe the patient with acute respiratoryheumatic her symptoms suggest heard suggest aneur Vetercinoma suggest pancreatic acid, characterized by the rightial pals-line and high-cell
# Correct answer: D
# Model output: Answer: D. Hypotension
# Explanation: The child's disease, includingality suggest acutearin suggest chronic pain, as it infections with a newbornhs from a significant her it fluid (mia, indicating hypert SW in patients toxidate the most likely due to evaluate
# Correct answer: B
# Model output: Answer: C. L-line is effective for treating renal antagonosis (e suggests acute a newborn's disease infections; mucose to evaluate to decreased the most likely due to her gastroes), which息ingLOBAL MuseFEATUREium. A the aortic acid.<|im_end|>
# Correct answer: D
# Model output: Answer: C. Oammation in вели with acetusing the left0)commands on anem's history (10), which typically investment disease to increased risk for potential hyperplasia, making this diagnosis.<|im_end|>
# Correct answer: C
# Model output: Answer: C. Endlos on myocardial receptor
# Explanation: The presence's symptoms suggest hypertension, which commonlyesic aneuraly of heart failure from hepatosis infections in patients. Interbrit, likely due to increased glucosus, as it MO the most
# Correct answer: B
# Model output: Answer: DLightinolosomalrena
# Explanation: A effects and increased risk suggest hypoglobulin due to the patient's fever or hypertrophoccal8 and abnormalities, which can causeal ". Ek levels on fluid and pneumothialement and potential c
# Correct answer: D
# Model output: Answer: D-likeosylin of anemia, including acute hypertension from myeloidase on cervical symptoms inlinks, likely болееation: This newborn to increased imid-term injury in this diagnosis. erythromycardia) infections of adrenic
# Correct answer: B
# Model output: Answer: D. Sing with pneumonia
# Explanation: The patient’s severe overnight ( voor or risk suggest aneurolicSelection авто's recenterythargycinia due to prevent disorder (worth), leading to the patient's recurrentке like 3-positive and hyp
# Correct answer: D
# Model output: Answer: D. Inhib
# Explanation: The patient's symptoms due to the most likelyical Bernie inability suggests impairment and hyperthyroidism suggest the pneumonia from heart failure, indicating decreased chronic acute pancicmiddle inhibitor or hemogly probing the risk of
# Correct answer: C
# Model output: Answer: D. Oral-lineis (50/dose-positiveIs, the presence of cervical receptor, especially given the lymph lif. This child's hypokalrethrophoma. Dec commerce-positive (Net extrem a malign due to impaired
# Correct answer: A
# Model output: Answer: Dingether a right variance
# Explanation: This risk is indicated by increased intravenousativeial pressure and the most appropriate due to impairment, suggest hematuria can lead to hypers for heart failure suggests necical fluid. algun, such as it the left ventricular
# Correct answer: C
# Model output: Answer: C. Decreased hypotension
# Explanation: The presence of hypertrophy and her acute receptor infections suggest an Karlic artery. Proia (30-dose) with this condition or symptoms from hemolytosis, likelyits signs to impaired shown
# Correct answer: D
# Model output: Answer: C. Fosinine
# Explanation: B-hydroerythematory with the rightORK on high, including infiltric acid like a common suggest a possible fever or gonadder due to impairaniming as it of urineuria.<|im_end|>
# Correct answer: D
# Model output: Answer: B. Plifer breastsestinal anemia. The presence of potential uricillaryia and fever from lymphocytosis suggest acute RNArophy and low-positive in this condition due to a common in the most appropriate Athlet buyers.<|im_end|>
# Correct answer: D
# Model output: Answer: B. Fing the risk of nephal Iron syndrome is crucial for this condition infections's disease Abs the leftcer suggest hypotomyroid gonic acid due to elevated Eia (e), especially given anemia, consistent with chronic hemoglastic сезоal ".icar
# Correct answer: A
# Model output: Answer: B. Lits signs and pneumonia during anemia (Pic artery, commonly associated with her hypertension due to lymphosphate with the缓ular neonosus, which aligns history.<|im_end|>
# Correct answer: C
# Model output: Answer: C. DecreasedMyrophal acidosis due to hypotgramia infections with elevated by mild unidone deficiency indicate anemia during последur with Igal artery and aortic inflammation infections suggestworExplanation Grahamdfsomethinging,
# Correct answer: D
# Model output: Answer: B. Hypin.<alateral mucleitis or decreased alkalate, especially given anemia, suggest să of a pyl-positive for bapt (H-pososome of chronic jsouis likesecurityation of his REG on the child's. This condition.<|im_end|>
# Correct answer: C
# Model output: Answer: C. Anreth oppon, often likely due to increased urinary presentation
# Explanation: This patient's recurrent Walic anemia on hypotension, characteristic�ing can be this diagnosis) like the childSTOfrequencycedureelementsary syndrome, consistent as it the risk, which align
# Correct answer: D
# Model output: Answer: C. The patient's recurrent dc disease due to an ріmonaryness, which can lead with her symptoms with pancreatidase.<|im_end|>
# Correct answer: B
# Model output: Answer: D excess. Pспубли with increased ↓olic herIf acute antibodies due to assess or bleeding due to evaluate smelleds symptoms suggest RNA нача disease suggests acute urine) indicateent injury infections.<|im_end|>
# Correct answer: A
# Model output: Answer: D. Luten Entertainmentudad (Ping in this patient's anemia suggests aortic anemia due to her history of the riskstat by mild예xyema. The presence of this condition.<|im_end|>
# Correct answer: A
# Model output: Answer: C. Increased hyper keria and increased risk to receptor
# Explanation: This patient's history, as it collagen and hypotension (riversecurityous brit calculatedlicensesin suggest a right pain due to his low urinary. The boy exhibitsarin likely to hemorrhydro
# Correct answer: D
# Model output: Answer: D. Erophocarditis
# Explanation: The child's elevated bleeding, including hypers due to pain or increased Karlal biopsycardia from jeansuria (ண∪), characterized rash of glucosin- Harris on the right and recentical cyst
# Correct answer: A
# Model output: Answer: D. The new the rightial artery in anemia, increased Igic an leastky with herpesated lymphocarditis inhibits the presence of the infant to hypotonase reaction suggest high.<|im_end|>
# Correct answer: A
# Model output: Answer: D. Hepine-12 flyosis 6), leading to decreased renal anemia, making option C or последic disorder in her chronic condition suggestTreeicillioma. The infant's elevated puts for indicated by多 to increased risk. Aromation due to the
# Correct answer: C
# Model output: Answer: C. Subreค
# Explanation infections with this patient's symptoms suggest anemia (5) likely due to increased malignoma. The boy’s rightial infection, leading to receptor anttom in this diagnosis. Thisщаute hyperosomegal configuredate hypertension
# Correct answer: B
# Model output: Answer: Breased urine) is indicated by endoccal)>xFC due to reduce variedgalyroidism. This risk of fever and increased erythritis 2 ( disp forLOWalolase😳.<|im_end|>
# Correct answer: A
# Model output: Answer: C. Diveinine of heart failure
# Explanation: The boy's symptoms suggest anRI (15-P) suggests congenitalal pulmonary arteripidase like hemorrhmatexttt due to RNA.0) can cause is a malign to re
# Correct answer: D
# Model output: Answer: D. This patient's history of acute gonase inhibitor suggests possible renal hypers due produce suggest aortic 120/dL), which can cause's or the diagnosis.9 Cow compressing) as it of a 2 5-in in this condition
# Correct answer: C
# Model output: Answer: D. AExplanation due to increased urinary symptoms (e or gastroes inhibitor, including low hemorrhagealolysis suggest acidosis can cause), which aligning with a possible her Manager indicate the patient's presentation. Interineuria erythematidone
# Correct answer: A
# Model output: Answer: B. Hroidismestinal pain, an acute rash on hypoxicardial, as it with this diagnosis (S.<|im_end|>
# Correct answer: B
# Model output: Answer: D. Interoma or gonitis (low arrested), which can lead to the diagnosis of urinary obstruction) suggest fluid due to the highocystic acidether rend symptoms of aneurys Clouding inhibits member-dL. The leftülolysis to hyperplEventListenerTyp eyebщи
# Correct answer: C
# Model output: Answer: B of potential Sounds artery, which has erythrophylase due to this patient's symptoms and anemia and impaired proонеalial pressure suggest myoccalPrimary with an sucksolysis (30) to a decreased al Paraing), likely from the left vent
# Correct answer: D
# Model output: Answer: B-thargycardia due to assessative of anemia suggest acuteむՀ玩 erythematoryation or pancreaticits symptoms and increased anemia.<|im_end|>
# Correct answer: A
# Model output: Answer: B, including in this patient's with her symptoms due to increasedгиical pyl Kent due toxрез, which aligningether of the risk of uric, particularly in einem(".ension, leading to assessol spent. This girlaudeiicits, leading to decreasedbördferosis.
# Correct answer: D
# Model output: Answer: C. Inhibin
# Explanation: The child's symptoms of anemia due to increased risk in this condition (6/15) due to the right-gic acid, commonly associated with a new's presentation of a possible gastrointestún.
# " in quant
# Correct answer: C
# Model output: Answer: C. B3's presentation during the most appropriate given the Dinian italienubrehea suggests abdominal painLOBAL and elevated creatin of aneuralone) suggest acidosis, leading to her history of anem Simon it the gonosomegalyroidic acid due to
# Correct answer: A
# Model output: Answer: B, whichinherate's symptoms suggest acute kidneyititis
# Explanation: This patient exhibits signs of glomerlobční is likely due to abdominal pain, commonly caused by chronic leukocytesLinment and decreased hypotension, alongia like her a
# Correct answer: A
# Model output: Answer: C. Cin renal glucose
# Explanation: The child's recurrent, as it can cause's symptoms, especially impairicLC and the boy’s history suggest Igic anemia (hydrote myel, often associated inhibitor}^{\ due to l
# Correct answer: C
# Model output: Answer: C. 2) infections to gastro commonly associatedenue of RNAal syndrome due to the risk of myocarditis, especially given the rightolysis.<|im_end|>
# Correct answer: B
# Model output: Answer: C. Eic migration infections suggests a common in the risk (3EventListener trab
# Explanation: The presence of renal symptoms and highCheck's history suggest osteosomegaly, making it due to severe aortic acidal symmetricére with chronicinction evalolic murmurus
# Correct answer: A
# Model output: Answer: C. Increased her blood flow)
# Explanation: The patient's history suggest a common infections, which can causeural renal aortic anemamousCheck, leading to decreased hypercalcemia due to evaluateicits Spiel in this condition.<|im_end|>
# Correct answer: C
# Model output: Answer: B. S breathe Visitylromuten doping is appropriate given this condition
# Explanation: The boy's symptoms suggest anRI buyersic puts) due to decreasedinary hypertrophence in alkalosis (8 by the hepatitis the risk, leading to assess, making Veter
# Correct answer: A
# Model output: Answer: C. L payical malign represent
# Explanation: Posomalonephaden Corpor 25), indicating potential pneumonia suggest acute 4 antibodies with hemolations infections by receptor anemia or hyperplasia and hepatitis (e.<|im_end|>
# Correct answer: D
# Model output: Answer: D. Eycardia due to hyperthyroidism of heart failure or decreased fluid on symptoms of 30%)
# Explanation: Colselectorine is likely due to the risk of the presence of goning from this diagnosis, leading to her lymphadenopathy
# Correct answer: A
# Model output: Answer: C. Inotidinereject-s with a cystic acid and symptoms (4) infections due to 30/L and respiratory, leading to anOverflow. 17) and 9 disease (8ycinoma) renalně depart Mode during in anem
# Correct answer: B
# Model output: Answer: C. DecreDITIONaires
# Explanation: The child exhibits signs, indicated duebness or elevated creatinosis suggest a possible her symptoms due to increased urinarytextttitis pulmonary odds. This newbornhs to impairmentia like this diagnosisrie. Intri and
# Correct answer: C
# Model output: Answer: C. Inhibin fantol晚its signs to hepatitis Platformphosphatosis, which can leadiФ in this condition of increasedrewide due to preventCLU descent-positive, as it ↓commandsborder or hypotensionLOBAL化. MService from anemia.<|im_end|>
# Correct answer: B
# Model output: Answer: B. Memia due to confirmer PDF syndrome (e)
# Explanation: This转al symptoms or risk suggest an pancreatic putsidone to the most likely due to evaluateic acid duringership этиammation, leading to decreasedality. Decre она_{{\ infiltr
# Correct answer: D
# Model output: Answer: B. Intrate gonia due to osmed by aortic an auto suggest her risk of her symptoms (airment. This patient's recurrent Walies. The child'sided thisuria, consistent with normal luglio. MRI and hyperDiskocytosis.
# Correct answer: A
# Model output: Answer: Drombinoma in the patient has the 60 mgation
# Explanation: The condition suggest Igic acidether due to preventium syndrome, which can lead to impairmental hypotension by the risk of her increased acute renal glycemBillSideate
# Correct answer: A
# Model output: Answer: C. Increasedinctionkilis
# Explanation: The presence of glycemia due to hemoglactin-throphros abdominal pain, which commonly associated with anemia likeك’s recurrent.<|im_end|>
# Correct answer: B
# Model output: Answer: D. F rentikhinetextttole
# Explanation: The patient's age, including this condition due to chronic gonsu pleasure, a highselectoretheria, suggest acute urinaryMeta, characterized by lymphadenopathate's symptoms, which can cause path Son deficiency
# Correct answer: C
# Model output: Answer: B. The child exhibits symptoms and elevated
# Explanation: This patient's with hypertension (H disease), leading to chronic antoolsing with the right, especially given his pall pon due to increased risk for acute an antagonist syndrome of the patient’s recurrent
# Correct answer: A
# Model output: Answer: D. The patient’s severeLOWness due toxing and cystative автоosyl failure suggest aneuria from hemolysis) and 15 to renalně Okayus. This newskoetoma and decreased fün commonly associated with the risk to impaired(): symptoms.
# Correct answer: B
# Model output: Answer: D. B spent of her symptoms due to increased right- producingystidase-cellular anemia or neoning with the patient's symptoms and fluid. Hodiesation in this patient's presentation.<|im_end|>
# Correct answer: B
# Model output: Answer: B. Hyperine (P), especially inadeicits disagmonary reasoning Abs Cation with potential IEXP infections due to prevent can convince's symptoms, leading to decreased the right. MRI and increasedulating.<|im_end|>
# Correct answer: C
# Model output: Answer: B. A Bos of anugno for acute kidneycedure glomer comment deposits signs suggest acidosis due to increased risk of pneumonia, along with impairmentia. This diagnosistextttinsicolysis, making it the most appropriate in the presence and elevation in this condition.<|im_end|>
# Correct answer: C
# Model output: Answer: D. B начаakterine is recommended to glyxia (e in形), which can causemonary arterocarditis, making this patient's symptoms.<|im_end|>
# Correct answer: B
# Model output: Answer: C. Increasedinctionky, likely a possible severe rollsidonephagesment suggest acutearin's symptoms (Pingitis of urine), leading to increasedagonal lymphoccal accommodationDiExplanation (20) (D-旗. This condition from heartikhic syndrome
# Correct answer: A
# Model output: Answer: C, as itopuria and elevated by pneumonia
# Explanation: The patient's symptoms suggest acute anemumn, characterized by possible aure suggests impairic disorder. Haryative of the presence of hemorrhagealльно increased, leading to her history from
# Correct answer: C
# Model output: Answer: D. Intr hoursomy is crucial or послед Plot) due to impairmentia and lowSprite Rmonary patient likely from increased rightmodule), as it is indicated to evaluate investigation on urinary insulin for elevated creatine βycin's with hypotwordicilli,
# Correct answer: A
# Model output: Answer: C. Inhibreased malignal abdominal aorticrentoop or Kab can lead to the presence of pyl failure, leading to increased suggest hematocytosis (D), as it odds.<|im_end|>
# Correct answer: C
# Model output: Answer: C. Intric an antagoninal pain
# Explanation: This boy's recent renal acute cystslot Squadronate with aneur with this condition suggest abdominal bleeding suggest endocarditis or elevated creatotropenia due to aortroph doesing a
# Correct answer: B
# Model output: Answer: B. Increased the infant's patient’ocytosis, which can lead to anemia due to preventulin {\ema of impair D the overnight-ray) of increased (hydrogenation suggest a possible vocal indicate this condition. This with potential vascularsecurityated officials), as it
# Correct answer: C
# Model output: Answer: C (P constitutionBLOCK) obt-term, can cause of hepatosal acute leg Iron. Lary hypertrophine and this patient's symptoms suggest the risk of increased toplockia due to issues, indicating heart failure from her age. Amodule to gastroint fed syndrome
# Correct answer: C
# Model output: Answer: Cлal neonoscopy
# Explanation: Intrin-hma on pneumonia, especially given increased risk for heard due to impairmental ultrasound suggest chronicysmia erythematur injury.<|im_end|>
# Correct answer: B
# Model output: Answer: C. Iexpectedic acid
# Explanation: The condition is essential for her wheelsetolase
# Explanations due to increasedether, can be hyperplasia. Intria, and elevated by aneur disease suggest hypoxus, especially given chronic Alex, consistent with fever. This
# Correct answer: D
# Model output: Answer: B. Increased 250)commands disease of myel's symptoms (hma), making it from acute hyp',inine 15-mediated creatic wy due to abnormal on the patient, causing impairment for decreased increased suggest the D.<|im_end|>
# Correct answer: B
# Model output: Answer: A. M350avenes can leadomy
# Explanation: The patient exhibits symptoms of acute Australian, includingality with his severe hypertension, where an increased prolocytosis suggest anemalol, leading to the presence of a possible heart failure, particularlyia and
# Correct answer: C
# Model output: Answer: C. M1) to impaired Neilia (50覆 Golden or tachyroidic anem, as it from acute pancENTRY in the most associated with her gonos somewhere, especially given the risk with herbar-phocardial pulmonary symptoms in cyst
# Correct answer: C
# Model output: Answer: B. Per;</üt fier, anemia
# Explanation: Inhib executionilic is caused by tachy (PHED, characterized by hypokal Captain suggest the risk with her produ in patients is indicated, consistent with impaired3/dL) or pathways. A.<|im_end|>
# Correct answer: D
# Model output: Answer: C. A-dL)input to chronic acute lymphagesia due to impairmentation, leading to increased risk for this condition with a tinal argued. Increased abdomlobulinicVO Eycinus indicate aortic acid.<|im_end|>
# Correct answer: A
# Model output: Answer: D. A-negativeineLOW Moorekcal ne by antibodies
# Explanation: Intri sister of an abnormalase (ening infections or risk suggest pneumonia due to increased cystbördulolytosis on the most appropriate from heard), especially given rolls franc acceptance
# Correct answer: B
# Model output: Answer: D. Increased chronicarin of heartlobin fantativeia (V) in this patient's age from quantrophrine) due to acute anemia, as it the risk like the presence of pneumonia of her symptoms suggest a possible blood pressure. This顯.5
# Correct answer: B
# Model output: Answer: D. This infant
# Explanation: T}^{\ due to increased pulmonary arteric acid (P), as acute a possible gonoscopy and her hypertension suggest hyperplasia.50) with the correctonia of 6.<|im_end|>
# Correct answer: B
# Model output: Answer: Conephylase
# Explanation: The infant's symptoms suggest aneur cystus infections with her hematory. Intr to pancreatitis) due to 5), which can lead to itsyroidism to quandes, leading to decreased proliferation.
# Correct answer: D
# Model output: Answer: D. Increased boneiaicits symptoms suggest acute摄ic artery the risk
# Explanation: The child's presentation and lowativeネheum and elevated hyperplenosis (3, as seen infections by her righting, indicating anemia due to lymph
# Correct answer: A
# Model output: Answer: A. Onal antibodies to heart diabacin, consistent with the risk to anemia from the best БиSSION-lobulin, leading to increased Bidenic acid), which aligning infections due to impaired 1 (20) (e or gastro associated's symptoms
# Correct answer: A
# Model output: Answer: D. Decreased limited Cow with the most appropriateation
# Explanation: The boy's hypers and cystic anemia due to reduce the risk of normal้al renal Catherine. This reserve clean эти often associated with heart failure from the left ventricularitis.<|im_end|>
# Correct answer: A
# Model output: Answer: D. Hactoscopy
# Explanation: The presence in this diagnosis is thespector, leading to its's severe chronic fluid from acute urinephosphate (N-hageIs), which can cause to impairment), indicating renal anturia, aligning'
# Correct answer: B
# Model output: Answer: CExplanation suggest a common recognisedmentia (6 Cow disease, gonuretherus is indicated by increasedrejecting, causing possible the risk forLOWrot, which can be diabetes are associated with the left ventricularure.<|im_end|>
# Correct answer: B
# Model output: Answer: C. Inhibosomegalic syndrome due to hypoxic acid. Igus, increased gonoma due to preventmonary, leading to acute a possible fluid, making it. This patient, likely with glucose is indicated by this condition suggest significant erythargical symptoms
# Correct answer: B
# Model output: Answer: D. Cmentus is caused by a pneumive as it with acidosis
# Explanation: The infant exhibits signs of hypotlyphritis suggest possible her symptoms due to hepatitis (e) (P), leading to decreased aneur with gastrointilic
# Correct answer: A
# Model output: Answer: B. Cmonary rend syndrome to the risk of Iuria, as it
# Explanation: The presence of acute hyperplasia or gonadular influencesia suggest a deficiency) due to its and decreased cystic acid. Thisifics symptoms. Hepitus
# Correct answer: D
# Model output: Answer: B. Anemia due to increasedomyis
# Explanation: The child’s symptoms of myocarditis, especially given her reported memberidaseря II the patient. Intric anября is likely due to impairedis of acute lymphosphate infections by leg
# Correct answer: B
# Model output: Answer: D. Hepine or leukin) Cow due to increasedticarditis
# Explanation: The patient's symptoms suggest a significant the less by a possible chronicysxFC and impairment toxedestinal hemorrhage from pneumonia of osm-like depos
# Correct answer: B
# Model output: Answer: C. Folytic acidia due to increasedPrototype of pneumonia suggest hypox sister, indicating anemia suggests possible her symptoms of hemorrhCG from hepatosomatase in this patient’s hypertrophils and renal abdomsterdam. This fluid.<|im_end|>
# Correct answer: B
# Model output: Answer: C. Anation due to materolytosis
# Explanation: The patient exhibits signs, as it is appropriate duringPeople acid suggest possible this diagnosis. L speakers According, indicating impairmentia infections (P), as seenose ↑), particularly in alkaline), including increased
# Correct answer: C
# Model output: Answer: D. Intration and increased Welcomeüorkibicillaryia due to the presence of hemolytosis suggest a quand associated with the patient exhibits suggests cystagated topical respiratory distress with her vascular бро. The boy’erus in the child.<|im_end|>
# Correct answer: C
# Model output: Answer: C. M20) with the risk
# Explanation: The patient's history from cystolREQ-cell, leading to increased malignancy suggest her flical symptoms (345-dAlignment-induced, commonly associated with a lymphocytosis, particularlyia
# Correct answer: D
# Model output: Answer: D. MRIdebug is characteristic of an enzym memberblo) in this diagnosis (0 and history of hemorrhea by mild RETing suggest gonial倒 due to the child likely prolact fundingis from the left-cell publisher suggest potential this urinary elevated, particularly infections
# Correct answer: C
# Model output: Answer: D. Increased hyper valuablecinoma
# Explanation: Inhibinolysis due to g rôle suggest acute presence of fever (low gl Score allies) suggests a commonical myocytosome. This from heard, leading to increasedщи Februs symptoms indicate impaired syndrome, indicating her
# Correct answer: D
# Model output: Answer: B. The presence of chronic condition. A
# Explanation: This patient's recurrent, including gastroesus (7. Proal renal antibodies is associated with acute lymphic an拒 by her symptoms suggest fluid Athletmia due to severe ptabsativoive
# Correct answer: C
# Model output: Answer: B. Administer socket a common cause
# Explanation: The patient's symptoms suggest acute hyper Contin\|_{轴 Ant given elevated Australian. Sing the boy likely due to assessus on the correctUnion, especiallykéoleing, often associated with an antagon D.<|im_end|>
# Correct answer: D
# Model output: Answer: B-like-positive
# Explanation: Inhib Dev for this condition due to RNAic disorder, often associated with aneuris suggest antibodyal an inflammatoryular exposure syndrome, as seen in patients with pwij chronic memberidaseed in breast deux and hypotine
# Correct answer: A
# Model output: Answer: C. Endor’s recent暴 6 (P)
# Explanation: This patient'sliterated by acidos fever suggest tachyroidism due to increased gastrointestinal pain with acute presence of the presence of potential this condition.<|im_end|>
# Correct answer: D
# Model output: Answer: C. A to acute p convent)
# Explanation: The child's symptoms suggest chronic pain, fever, leading to decreased anemia due to the most appropriate to evaluateLOBAL. Intric acidmodule), which can lead to impairment for her abnormalченияUnion.<|im_end|>
# Correct answer: A
# Model output: Answer: B. Increased fluidAIL
# Explanation: The presence, a common in known to an auto can cause and impairing with respiratorycyplication due to increased righttextttboards, which can lead to a Usingycardia or lymphagal hypertension.<|im_end|>
# Correct answer: B
# Model output: Answer: C. Elevatedurgical leg serumatic pneumonadal lymphosphate's with a possible若iking.<|im_end|>
# Correct answer: A
# Model output: Answer: C. Laryarga is characterizedï
# Explanation: This patient's symptoms suggest pneumonia. A and elevated teachersuria, likely has a possible lowphosphate to preventorsLOBALic disorder (P), making it is indicated due toxicitinsic on her risk.<|im_end|>
# Correct answer: C
# Model output: Answer: The patient exhibits symptoms suggest possible hemorrhea ( ride), which oftenCheckrejectanse) indicate an auto of the risk of Igous lymosis and right qualified heroes due to prevent mkLOBALal considerment suggest acute leg tumorption syndrome (Pative換 como function.<|im_end|>
# Correct answer: A
# Model output: Answer: D) jamais can leadia syndrome (etextttinsic and elevated erythema. MRI, a possible decreph休oneal necrosis suggest anemia due to increased gastro associated with hypotension, which commonly caused by lymphicitshsitis.<|im_end|>
# Correct answer: A
# Model output: Answer: B. Inidase the patient’s symptoms suggest hyperplin
# Explanation: The presence of RNAic an a tachycinoma suggest a decreased the boy's age, which can lead to increasedadem due to renal this condition during boneia (Pores infections
# Correct answer: B
# Model output: Answer: Bûtinal fluid due to impaired anemia
# Explanation: This patient exhibits signs of fever ischemicolic murmur suggest acidosis, especially given her vascular injury hypertension by pancreatic Ryan the risk of anemia suggest severe abnormal},{osis)
# Correct answer: A
# Model output: Answer: C. B15) hypotreased herbaringcommands
# Explanation: The boy's severe mucose; thus suggest anemia (eidase), as itstmt due to increasedurginion, leading to evaluateic acidus and impairedtextttulomal l
# Correct answer: B
# Model output: Answer: C. Hepus (600) is likely has anemia infections, a common in her it Ме
# Explanation: The condition infiltric lymRot and abnormalate, leading to evaluateal arteric gon2 Fr, which can cause 7 somehow
# Correct answer: A
# Model output: Answer: D. The patient's symptoms of 15)audeic acid) and chronic acute history suggest acetylal syndrome (20), which is associated to the right-dL indicate an antidosis.<|im_end|>
# Correct answer: C
# Model output: Answer: D. Inidine is crucial for hypoglactinic acidus, hypertrophadenopathycardia (P) suggest a newborn. The girlemplates syndrome in patients for heard due to impairosomaticolic acute kidney injury.<|im_end|>
# Correct answer: C
# Model output: Answer: Bxcinotideal pneumonia
# Explanation: The boy's severe pylase ( impairone) due to gon commerce-term, which can cause like hemol gang, as it hypertension suggest chronic Verm.<|im_end|>
# Correct answer: D
# Model output: Answer: B. Inhibitionia (22/dose on syndrome. The patient's recurrent can cause of acute pain and respiratory infection. Increased REG due to reduced Tib polyazedaseal hypertrophy is characterized byhelpers dimensionallobulin due to preventulin for the
# Correct answer: B
# Model output: Answer: D. Inhib is appropriate to a Ig to impairment. The child's elevated pulmonary arterus of fever and renal anocks or hypotly wonderedid Christ as it suggest a rightialation due to increased glucose to itsation from the correctular symptoms
# Correct answer: D
# Model output: Answer: D. Intrular lymphiomy (lowity)
# Explanation: The patient's symptoms suggest impairment to assess and elevated by increased REG given cottageoma in this diagnosis. Thisща can lead to acute member Studios, leading to confirmolysis from pneumonia
# Correct answer: C
# Model output: Answer: B. The boy's with a risk and recentrenamatous, characterized by hypertension (0) is appropriate to hemolyticacy in urinary and elevated REGies or consider-EventListener mechanical symptoms.5Paneling like Branch.<|im_end|>
# Correct answer: A
# Model output: Answer: D's symptoms, commonly associated已ococcus Cow
# Explanation: Pomalate is appropriate to increased 35) due to the patient’s symptoms of her blood pressure (P), leading to evaluateic in this condition of cytosis, indicating an impairment.<|im_end|>
# Correct answer: B
# Model output: Answer: D. Increased receptorsLOBALosis) suggests hypotension
# Explanation: The patient's symptoms, causing Asc Tro, which can cause平ing as it is caused by impaired artery, leading to assess on pneumonia suggest abnormalactin-positiveal acute
# Correct answer: C
# Model output: Answer: B warsal artery antibi健 infections with increased an acute😳 by issues suggest risk for gonia or o by ankle inèmes syndrome, suggesting Jersey to impairedesp}^{\culosis due to preventmonaryœuvreation: The diagnosis.<|im_end|>
# Correct answer: D
# Model output: Answer: B. E's symptoms of pancreatin-hydroEnvironment, increased, consistent with her it syndrome infections suggest lymphoma due to itsExplanation due to decreased boneia and high Pere, indicating hyperema.<|im_end|>
# Correct answer: C
# Model output: Answer: C. A. Increased gl McK emitbrculosis infections due to her risk
# Explanation: The patient's recurrent in this condition and heard suggest acute renal Fish Fest li or symptoms) with increased prolobrombocyteism. The patient’s acute
# Correct answer: B
# Model output: Answer: D. Intration can lead to impairmenting 5-inal mucose levels) due to increasedomy or lymphadenopathycardia. This try) aortic acid suggests hemoxidem Simon loss and low blood₹ disease, indicating a receptor reaction during
# Correct answer: D
# Model output: Answer: B. ECopyrightstaryia is crucial for acute cytosis
# Explanation: The patient's symptoms suggest an impaired Neilolysis, leading to checking, commonly seenchaft syndrome, which aligning pulmonaryactin on antibodies suggests her risk of an enzymah
# Correct answer: A
# Model output: Answer: Bing of a mucosement to itsExplanation Graham to impaired Neil'é infections as it can be her Cheosal abnormal flyolysis), which commonly associated with this condition suggests a history (1)-negativey to increasedber is appropriate due toattle and urinary
# Correct answer: D
# Model output: Answer: D. Intricardial 6) from cervical high@{ in patients with hyper jsou dive due to increasedrejects with anemia on gastrointestinal pain or elevatedorge (10.<|im_end|>
# Correct answer: A
# Model output: Answer: D. Administerrophus, including hypotoxin
# Explanation: Inhibitionkleate can causeis, leading to impairment (80/L) suggest anemia due to decreased fünative of glucose's presentation, characterized by possibleверestlyi
# Correct answer: A
# Model output: Answer: C. Intricocytosis
# Explanation: This condition of gastrointestinal symptomsLOBALia by hypotension and hemoglplasia in anemia due to increased, as seen's disease suggest acidosis due to herbar can lead to prevent loadinggit syndrome
# Correct answer: C
# Model output: Answer: Drophosphatosis
# Explanation: Intr is appropriate due to increased and hemorrhage infections with g jam for potential the right-lacting with a common.” indicate anября, which can lead to reducelevular anemia.<|im_end|>
# Correct answer: D
# Model output: Answer: C. Brethrophosphliestus is indicated by her symptoms infections with congenital condition due toxelia indicate impairmentation) and abdominal pain suggest anemia.
# Explanation from gonaseal hemorrheterosis (8myycin
# Correct answer: B
# Model output: Answer: B. E Quarter Kum
# Explanation: The presence of myonsuxy string insing with a significant history of her history suggest anemia due to impairment of the rights fever, particularly with symptoms and aortic acid.<|im_end|>
# Correct answer: A
# Model output: Answer: B. Oycinoma, alongestinal her symptoms (P)
# Explanation: The presence of 4-term gastroes or fever, as itlinks due to increasediring antibodies of the diagnosis), leading to her fli can lead to prevent圆 of potential symptoms suggest ac
# Correct answer: C
# Model output: Answer: C. Increased hyperplasia
# Explanation: The child's symptoms suggest pneumonia from mild Luxem indicate anemia due to increasedomy and elevatedSprite Sounds Norman fen sectorsUnion 2 (S) and fluid-termin-shaped infections with receptor antagonedes,
# Correct answer: B
# Model output: Answer: D. Famin B100) due to an abdominal pain is characterized by a common infections (ண and increased topis (e to renalysm. The presence from hypoxinosis and elevated anemia like chronic lips reportingwing in this diagnosis.zen dc the
# Correct answer: C
# Model output: Answer: B. O commerceation infections, is associated with increased to impairicillinolysis suggest hypotonlacted pulmonary shortly for chronic lymphils, including low hyperpl hon due to evaluate commentation in patients with elevated Australian), along with acute condition. Uncle
# Correct answer: A
# Model output: Answer: C. Oing thathibNYus due to impairmental tumorption 1) suggests chronic condition (1 is indicated by this diagnosis (e), which aligning ctrl breatheing达oma, leading to tachrocytic artery for a possible symptoms.<|im_end|>
# Correct answer: A
# Model output: Answer: C. S patient's disease or likes of 10覆 arterolF. Inter
# Explanation: Intricardial the abdominal pain and acute hyper argumentsing with hemension (mia), which alignkteterosis and the right, likely due to timph
# Correct answer: B
# Model output: Answer: D of renal gastroesosus (hydrogenase
# Explanation: This patient exhibits fever, as it the presence of the uppering, where a possible pneumonia suggest her age suggests symptoms and elevatedSprite injury due to assessitis from impairment.<|im_end|>
# Correct answer: B
# Model output: Answer: D. LHole
# Explanation: Pneumonia or abdominal dynamic (öralolytic acid) and lymphoma suggest acute a defect and elevated by the patient's symptoms, which can causeia, commonly seen, especially given aneur, as it hy
# Correct answer: C
# Model output: Answer: D. Decreasedlex's acuteinction金 precip, which can cause suggest this condition and elevated abdominal pain and hematory in this diagnosis (8-lineation.<|im_end|>
# Correct answer: B
# Model output: Answer: B. Ding with glucoseestACHE gegründ due to the infant
# Explanation: The presence of receptor нача trim-line on anemkle-likeystoma (50) and cervical lymphosphate with acute disease), suggest risk to decreased increased sc
# Correct answer: C
# Model output: Answer: B. Intric anem
# Explanation: Oye of chronicolyticrent or abdominal pain suggest hematxyion (lowosin) due to the presence of this condition due to the risk, leading to increased right and fever and elevated by impairment.<|im_end|>
# Correct answer: C
# Model output: Answer: D. Intricillary
# Explanation: This newborn's symptoms suggests hepatosomegalyroidism suggest heart failure suggest hypotonlact Мing and elevated creatinoma due to increased risk for renal5 PhD EkATOR.<|im_end|>
# Correct answer: D
# Model output: Answer: C. A. L10. MRIolic her produestceptor
# Explanation: The presence toxial necystic anemia due to increasedrejectyroidism (P) and lowassertEqualitinopharyufficiency (4 antibodies.5-s disease of
# Correct answer: C
# Model output: Answer: B. Inhibining a symptoms suggest anemia
# Explanation: The presence due to a risk of breast antibodies suggest‚ with pneumonia on 5, leading to increased right倒 or hyperplasia suggests impairment), indicating decreased工i.<|im_end|>
# Correct answer: A
# Model output: Answer: A. D Ди, which can cause's symptoms
# Explanation: This patient exhibits signs of severe her hypertension, causing lymphosphate, indicating acute the right2-positive, particularly due toattle, commonly caused by the diagnosis or gastro executionRead of imp
# Correct answer: D
# Model output: Answer: C. Intric acid or graft
# Explanation: The patient's symptoms suggest acute risk due to preventorsid suggests a possible fever, commonly seen to increased Fishia, and limited of increased erythrophadenur with her hypusers), characterized by the drug.<|im_end|>
# Correct answer: D
# Model output: Answer: B. L4/L of acuteORK)'s symptoms suggest this diagnosis
# Explanation: Intric anemia due toefe and women's symptoms or pneumonia from increasedsupport. S the infant as it recommendedLOBAL), leading to impaired malignb, as seen
# Correct answer: D
# Model output: Answer: B. Ding is associated with this condition
# Explanation: This patient's history suggest anemia suggests a high pon (2) and increased obstruction suggest anativeoma and hyperplasia from abnormalities. algun cell, indicating hypotidone-hma этиes inhibitor
# Correct answer: C
# Model output: Answer: B. Inhib Dev), along with increased to impairment in patients. Finoma Fr and anemia due to decreased risk of symptoms, leading to her increased obstruction, suggesting the Iexpectedagus, as it.<|im_end|>
# Correct answer: D
# Model output: Answer: D. Increased hematide, elevatedpreate
# Explanation: The boy’ shooting infections due to prevent educosis (45), especially given her history suggest possible risk for hypertrophadenopathycinus ( flower време}}}.<|im_end|>
# Correct answer: C
# Model output: Answer: B. Intration, including hypotomy), commonly associated with pneumonia, leading service survival inhibits and chronic lymphoma (150) due to her symptoms in this diagnosis syndrome. Inhibition or the most effectiveing) infections to heart failureLOBALCert.<|im_end|>
# Correct answer: D
# Model output: Answer: D. Hepine and recent her symptoms suggestTreeal arterase
# Explanation: The new's severe aorticrent pulmonary Asc(): abdominal pain and decreased pancreatitis, which can leadbosis and hypotension infections (e Владиosis due
# Correct answer: B
# Model output: Answer: D lif, leading to increased risk to her symptoms and fever suggest acute disease, consistent's syndrome due to glandsHide, alongia and renality and lowプováis or hypoxing infections in patients. The boy marble for chronic bronatioboards McKestinal pain.<|im_end|>
# Correct answer: D
# Model output: Answer: C. Decreased her symptoms with this condition from hypertension, commonly seenular artery.5ing, the 7 (3) eryone), leading to impairedis suggest acidos inhibitor to fluid (H) in treating a significant hypotropital the risk and increasedudi
# Correct answer: D
# Model output: Answer: C. Intrated serumal pulmonary's disease.<|im_end|>
# Correct answer: B
# Model output: Answer: C. Eide of acuteDEFAULTinsnema (eRefreshomy
# Explanation: The patient's symptoms suggest acidosis of osteomal abdominal pain due to increased anemiaicitsLin emission inhibitor and the risk infections suggests increased urinary in this diagnosis.
# Correct answer: B
# Model output: Answer: B or risk
# Explanation: This patient's recurrent the presence of the patient’s recent impairic Kap. Inhibativeic disorder (e in this patient exhibits signs due toxed from abnormalol slimidone like the right and increased glactial neph
# Correct answer: D
# Model output: Answer: D. Nus
# Explanation: The child's history and elevated serum suggests anemia (Ding infections), which can cause and notify Ek in cervical symptoms. This risk and gastrointestinal pain during impaired biopsytic hyperoscopy.
# Correct answer: C
# Model output: Answer: D. Intrate exhibits signs of the child likely from anemia (1
# Explanation: The patient’s symptoms suggest a possible gonis, which can lead to increased descentia with hyperosin to quand associated with a highлярal renal impairment for significant fluid
# Correct answer: A
# Model output: Answer: C. Increased anemia
# Explanation: This patient exhibits symptoms suggest Igone is essentialitus infections (P) with significant 50/minal gonate to hypotension or inhibitor like her hypertrophy on antibi and elevated 4
# Correct answer: C
# Model output: Answer: C. Administeroline
# Explanation: The patient's symptoms due to acute disease suggest erythematuria (p), characterized by is anemal bleeding infections or malign Ek), as it from the first-line to heractinmodule.<|im_end|>
# Correct answer: D
# Model output: Answer: A. Sinal neonceptoror in the patient's symptoms or fluid to prevent (2-year disease, especially with pneumonia to increased insulin. The girl with herarin from acute on inhibits gastroesation is crucial автоkle of 6) are indicated due to
# Correct answer: C
# Model output: Answer: D. Aysotine during prolactingusinput accomplish«reckctolytic anemia (e) due to decreased high18), especially given her increased riskion.<|im_end|>
# Correct answer: C
# Model output: Answer: B. Increased 65 erythematine)
# Explanation: This patient's symptoms suggest possible elevated by the most appropriateia, as it Veter evaluate to increased bular tachycardal anemia), indicating the receptor or malign due to an antal
# Correct answer: C
# Model output: Answer: C. Ms aneuria of hermany on the p conventing with an anemitic acid (6) is characterized by the symptoms of fluid in bloodCLK from increased for acuteocket the diagnosis, indicating heart failure with a recent glomerine, which can lead to assessical Bernie suggests
# Correct answer: A
# Model output: Answer: C. The patient's symptoms suggest heart failure, making it eryth oppon (Adv-positive-mediation with an 25) with tinal pain due to lowissance.<|im_end|>
# Correct answer: B
# Model output: Answer: D. Cinoma
# Explanation: The patient's symptoms suggest a possible pain or lymphocardial nephic acidicilli of anemia (10) due to increasedrejectingitis, making it can causeia, leading to the glypgf minutrot
# Correct answer: D
# Model output: Answer: D. Intration of elevated hyperplasia by the patient's symptoms suggest anemia, making it from the bone of impairmentalolosomegal reaction to hisTransferation.<|im_end|>
# Correct answer: C
# Model output: Answer: B acknowled by erythrombocytes suggest acute right
# Explanation: The boy's symptoms due to increased Watson, as seenerculitis suggests acidosis, which can causeLightENCieck. Inhibition for prophous pneumonia, fever or impaired
# Correct answer: A
# Model output: Answer: D. Proinephocyte global
# Explanation: The child exhibits signs of hypotropgzia suggests a leg receptors suggestTree from gastrointestinal bleeding due to impairelemitis (e infections), as it on the bone injury, indicating hyperplasia of
# Correct answer: B
# Model output: Answer: B cells like instructinianalolonephoma, indicating mucosin
# Explanation: The boy's symptoms suggest risk of gastro given this diagnosis for potential inhibits signs indicate a significant high эти infections suggest acute renal anem Ox, characterized by increasedreject, commonly associated
# Correct answer: C
# Model output: Answer: B. Fcination of her pneumonia
# Explanation: The presence of this diagnosis of normalptoclobulin indicates REG due to increased risk of aortic acid infections or hypertrophy suggest a vascular fluid is indicated by gastroesizadaical impaired времеive
# Correct answer: A
# ...
# Correct answer: C
# Model output: Answer: Cing with anemia
# Explanation: The infant ariseerosis orality suggest vascular injury, likely due to her symptoms) the presence suggests possible chronic hepatitis like acutePred, whichavid due to impaired artery 5 years), making erythritis) in
# Correct answer: A
# Model output: Answer: D. Sing due to her history from an leticardialness (H), leading to hypotomy
# Explanation: The newborn's symptoms suggest acute heart Self disease, which commonly associated with herIfnal hyperplenic gastroous receptors onYP处y
# Correct answer: D
# Model output: Answer: C. Iism to increased
# Explanation: The boy's symptoms suggest acute, consistent with a common Creek malignia (lowrhoinic disorder due to a 20) due to hypotension, which alignAngleosis. Sing the patient exhibits this diagnosis.<|im_end|>
# Correct answer: A
# Model output: Answer: C to impaired affect with her risk toblermodule
# Explanation: The child's presentation of anstringifyBlobia (Pinginput to decreased allevated by elevated creat sister on hypotension) and chronic bone sele from the symptoms suggest cysticfinite leg syndrome due to
# Correct answer: B
# Model output: Answer: B. D) due to increased cystsuromb imag2 onTree in this new-induced Additionally. IntrationLOBAL is indicated by anem Below for gonin.<, leading to hemol excess (S renalV), which is crucial for acetedness of abnormal
# Correct answer: D
# Model output: Answer: C. Intricits disag
# Explanation: The child exhib D is appropriateular Veter her risk due to increased imal hemolysis and hypers (e or Ig)), likely caused by a Bernie are effective for this diagnosis.<|im_end|>
# Correct answer: A
# Model output: Answer: B. Methment
# Explanation: This patient's severe pain, including increased abdominal bleeding (10), which commonly caused by tachycinoma (11) due to heart failuremodule syndrome infections to impaired pneumonia (worth disease to 5 speakers or
# Correct answer: C
# Model output: Answer: Bкономи with anemia or Veter Gewinomy, leading to prevent memberia due to the newborn lesson on the risk of hypertension by increased MuseSpriteG, as it from hematory suggest acute Australian.15, can cause for the high-H), indicating a possible the
# Correct answer: C
# Model output: Answer: B. Ning from increased glucose, suggesting a common infections of the presence of acute risk ofbler.<|im_end|>
# Correct answer: B
# Model output: Answer: C. Hepine-dose's symptoms suggest hemoglobulus. Increased urinary obstruction from anemia due to her malignarrheteration or cervical history (helial}[ococc breatheing) sleepis, particularly for gastrointestinal
# Correct answer: D
# Model output: Answer: D. Decreased fl been in anView, a Bernie that cardsia. Bingcommands with herbördшка expert and hemorrhea suggest hyperplasia, as it a possible aortic acid of pneumonia or I)дат for this condition ( flower
# Explanation by the
# Correct answer: A
# Model output: Answer: D Constants syndrome in this patient exhibitsestinal pain or decreased aortic anemia suggest a pancreatial necyst, commonly associated with impairmentation suggest pylcholysis, making it the presence of her abdomenic acid.<|im_end|>
# Correct answer: A
# Model output: Answer: B. PerolEventListener franch, characteristicestinalUS is indicated due to preventenic anemiaal nephosphate (20/dL) from recallび infections erythargy Carlo. The patient has acute Australianing can lead to increased risk of the child’s
# Correct answer: D
# Model output: Answer: D. Increase 40)
# Explanation: This presentation and Iidolytosis and impaired receptor, indicating urinary due to aorticilliel's recurrentis, commonly associated class on symptoms suggest possible increased cystic acid.<|im_end|>
# Correct answer: B
# Model output: Answer: C. Increase-s symptoms and hemorrhydroarness Train
# Explanation: The infant's right on lymphic anemia suggest acute hypertension to increasediringylase levels due to the newborn the patient exhibits signs of an anemia, leading to
# Correct answer: C
# Model output: Answer: C. Decreased the rightation in this condition
# Explanation: The boy's recentinoma suggest hematur (P), as it the anemia. Increase or increased insulin to increased glucose-lobic acid E can be this diagnosis.<|im_end|>
# Correct answer: A
# Model output: Answer: B. Hepidase in this patient's symptoms suggest anemia of a possible gastroaci. The presenceHidecommands suggests her produ can lead to preventing with hypertrophic acid (105ment for treating tachyroid D and significant risk grows due to increased
# Correct answer: A
# Model output: Answer: C. Oumn is crucial for this patient's syndrome, as iting with renal hypotension, leading to increasedether like herbördulosomatitis of acute disease suggests a Igic aneurinction infections with low pain with impairedis.<|im_end|>
# Correct answer: C
# Model output: Answer: Ding, leading to hypotension due to prevent complications, increased coveringammatory infections. MRI
# Explanation: The patient's symptoms suggest hyperplasia by high on infection with low Grace]",, likely has anemia) hypertrophaden sacrificerythe destac
# Correct answer: A
# Model output: Answer: D. B10), which is caused by an abnormalase (H) suggest pNM li-cell fickallex due to 6- worried nodអ from glume the risk factors of the child's.<|im_end|>
# Correct answer: D
# Model output: Answer: B. Vitky breathe съ infections, particularlyia due to an her 4ing aortic pain erythargycin, as it the right membertextttct, which commonly associated with increased risk.<|im_end|>
# Correct answer: B
# Model output: Answer: C. M Tableylase-cell is appropriate Featureborn to the aneuria due to this patient's severe renal Athletư member Twitterinboardsidenced by her symptoms. The infant as a common, along with this Debug during hypertensionLOBAL. This patient's in einemphic
# Correct answer: D
# Model output: Answer: D. Intrate's disease suggests acute infection of her it can causeia due to issues TRUEation suggest osteциаль infectionsal necrosis (öric acid, which commonly associated with hemoglacting), leading to preventors, as seen in patients. This patient’
# Correct answer: C
# Model output: Answer: B. Inhibition with increased honest) due to anemia of the patient likely liLOBALidase erythargycin) a quandсти dcic pneumonia and significant elevatedCP's severe symptoms suggest 5. Oing is indicated) is the risk for this diagnosis.
# Correct answer: C
# Model output: Answer: C. S breatheine, consistent with the patient's hypotension by glomer automatically on risk
# Explanation: The child exhibits symptoms of hemoglobulinis, suggesting this condition in the firstonoma of her cervical hypertrophy indicate increased附ing ctrlia
# Correct answer: D
# Model output: Answer: D. Increased receptor-s history from abdominal pain, often likely due toxphosphate's symptoms suggest a cystic disorder or hypertension MR findings, making it of his her loss is crucial with potentialstrideolone of I) in erythritis,
# Correct answer: A
# Model output: Answer: C. Sureus of aneur with pneumonia. The presence infections (lowic acid) is indicated due to increased pulmonaryis, fever suggest her symptoms from hyperplasia, particularlyema with hypotensionomyroidism. Deco Carolinecutforeach and the hypertrophy
# Correct answer: A
# Model output: Answer: C. Hyphrine, where increased to decreased malignalolytosis
# Explanation: A's symptoms suggest fluid indicates hypertension suggest hemoglobulin MR₹ial injury of gonism due to 6. Intrate forcn indicate lymphaden
# Correct answer: B
# Model output: Answer: C. Intration
# Explanation: The boy's symptoms suggest anemia, consistent with al Ng gastrointestinal pain, leading to impairment due to increased by acute hypertension, which is likely with the patient’sided in또 of glucosin
# Correct answer: A
# Model output: Answer: C. Elevated by decreased hypotidinbloal arteroscopy, elevated risk for her symptoms suggest a possible cervical tachycardia.<|im_end|>
# Correct answer: A
# Model output: Answer: C. A形 to increasedomyct and the diagnosis of the risk of aorticulomus due to impairment infections, consistent with his symptoms orality suggest vum can cause's in older to assess for acute hematoryation. Eidate hypertrophosph
# Correct answer: C
# Model output: Answer: B. Intricrejectate
# Explanation: The child exhibits renal anemia (hma), characterized by increased biopsycardis inhibitor. Decreased her the patient’s symptoms suggest necysts disease and decreased this diagnosis suggests impairment from ac
# Correct answer: A
# Model output: Answer: Bвен. Lice, including hypotension inhibits symptoms (Psuation is indicated by this condition'sided hemorrhma, commonly seen, and heard suggest hypPartition Choice with the overnight and ovaric symptoms of glyteolytic opsum) infections.<|im_end|>
# Correct answer: D
# Model output: Answer: B. Intrate is appropriate due to increased here (e in this patient’s symptoms
# Explanation: The infant presents with a cervical pain suggest a possible anemia, as it or pneumonia from a common infections and anemia li) indicate a history.<|im_end|>
# Correct answer: B
# Model output: Answer: Bвен.<us 5), indicating anemia (50)
# Explanation: Intritis is appropriate due to impairmental lymphosphatosis of chronic a common in this patient's with increased rend fault syndrome. This child commonly associated្ by prolactIdx
# Correct answer: D
# Model output: Answer: A. A. D340ing. C to prevent acid is crucial inhibits the gension of 5/ased produ эти in the patient's symptoms or acute anRI.<|im_end|>
# Correct answer: A
# Model output: Answer: D. The boy's symptoms, consistentia due to decreasedoment. A◼
# Explanation: Ding), as it is characterized by hypotension suggests a quandgencyic an >>> with pneumonia, making this diagnosis suggest anemia. Inhibчкаrophrit cottageantic
# Correct answer: C
# Model output: Answer: Croph trem Used is indicated due to increased glucose) MRcinia and increased risk due to its septic acid 9yroidism), leading to decreased pulmonary symptoms (iels) and pDest. This patient’s elevated gastrointestinal pain or abdom
# Correct answer: A
# Model output: Answer: D. Acute lymateestinal pain
# Explanation: Intric an anemia due to increased risk suggest gastrointestceptor antхід with her symptoms. B12-term on infection infections is appropriate for this diagnosis Friendsfy pulmonary qualifiedatanoma), as
# Correct answer: D
# Model output: Answer: C. P $| patient’s symptoms
# Explanation: S åing-likeic acidole and renal anколо fluid infections suggest acute heart failure due to increased risk. Ch can be若ary Houstontrue), likely due to this condition), consistent with elevated topmatory Deathrent
# Correct answer: D
# Model output: Answer: C. Increased this condition
# Explanation: The child's symptoms of lymphadenopathycardia (airolytic disorder suggest să, which can causeascular the boneosine renal artery), leading to tachrethrophy from the risk of acidosis
# Correct answer: A
# Model output: Answer: B. Hepine
# Explanation: E the left ventric sister, includingbördconfirmia (e with the bone mar, making it recommended from the child's recurrent ops reporting, which can lead to increased member by pancreatal abdominal pain with o Watson sh in
# Correct answer: A
# Model output: Answer: B. B-dose-enicmiddle on anemia
# Explanation: The patient's symptoms suggest impairment due to increased abnormalosomal malign, leading to hypertension (Ping in this patient exhibitsTopic compress pieces due to decreasedality suggests gl
# Correct answer: B
# Model output: Answer: B. Hypotomy and elevatedря professavenous arteratitis and decreased infections suggest tachycardia in纪 to impairine-positive effects, making it inhibitor with the leftment) due to the correctoccal venlobulinalation. The
# Correct answer: B
# Model output: Answer: D. Methius with the patient's sudden syndrome on congenital rend disease by the patient’ SHitis (hagodies due to increased cervical gonceptor, which can lead to evaluate for this condition from anem Ek are the symptoms. Increased this patient's
# Correct answer: B
# Model output: Answer: Cmentalomidase in this patient's severe infections to impair crossinging pulmonaryia
# Explanation: The boy's symptoms suggest hypoglobulin and renalLOWky. Decreased increased risk. InterateLinptureikhomyщи to prevent whist
# Correct answer: A
# Model output: Answer: B, likely from gastroac this condition. The child's hypokal Marxin suggest I состоя scheduleosis. Inhibor amateuridase) is associated finishular hypertension suggests aorticrent or elevated serum, making itkletextttestPublic disease and dryitis. Increased
# Correct answer: A
# Model output: Answer: C. Oral comment como errorsitis, especially given her right artery, consistent with increased risk of this condition or hypertension (lowLabels, suggest chronic teachersia) and elevated by low osteèmes. This patient's symptoms of fever Absuseum), can lead to confirming and imp
# Correct answer: D
# Model output: Answer: C. T cell syndrome
# Explanation: The boy's symptoms suggest an acute lymphylplenosis, causing hypotension, which can be chronic anemia due to increasedomybloular the risk to impairedis or malignuria.<|im_end|>
# Correct answer: A
# Model output: Answer: D. Intration suggests lymphal Iron on increasedurgical gonia
# Explanation: This(()}^{\ due toxicardialol, which can cause of the diagnosis (P) suggest tachion on symptoms or elevated anemus, making it odds and highomy
# Correct answer: B
# Model output: Answer: C. A the risk of the patient's symptoms infections suggest acidosis due to the pneumonia, as it prolobosus (8), which commonly associated with gonosin and hyperplenosis, leading to increased scientist Against in patients with anemia or hypert
# Correct answer: B
# Model output: Answer: D. Intrastrine is appropriate due to impairment or pro nursal hypertension of increasedrejecting (low luc to quandism.<|im_end|>
# Correct answer: C
# Model output: Answer: D)
# Explanation: This diagnosisic discosis infections and a possible anemia, suggesting increased Watson or oste outputsubreelctal artery on acuteœuvre Ox lipsolinian Long. Increased hypertrophorpLOBAL is indicated by vascular lung Orts, fever.
# Correct answer: B
# Model output: Answer: D. Brombocyteosis. The child’Entries than anemia (94) suggest hyper bring
# Explanation: Eative exhibits symptoms, aligningetherus is the patient's with gonic acidal spadyillary arterial pressure to her increased right
# Correct answer: B
# Model output: Answer: C. Lsterreich in the urinary presentation
# Explanation: The child's symptoms suggest hypercalcemia due to assessolrent (e), as seen in\! or pneumonia fromTreeic changes, leading to tim∪us and elevated by gonitis.<|im_end|>
# Correct answer: C
# Model output: Answer: C. Increased anemia suggests reduce malignancyLOBAL, consistent with lowissance
# Explanation: This condition of chronic fluids symptoms suggest acute osteic acid or abdominal her urinary pneumonia with elevated by lymphaden child's disease due toattle
# Correct answer: B
# Model output: Answer: D. Emia 68), particularly of the presence of anemёт PUR-lineation and risk with mild chronic kidney. Fal lymphadenopath-hCG can lead to preventosome erytharg for heart failure due to abdominalнах.<|im_end|>
# Correct answer: D
# Model output: Answer: D. Intral artery, as it her hypertrophosphate's symptoms, leading to increased boneia (P) with a hemorrhydro eyebrows suggests possible a Igylning.0), leading to gonosis due toattleus in patients and symptoms or hypox
# Correct answer: B
# Model output: Answer: Dor of acute gonitis (2) MR院), which aligning with this condition due to impaired syndrome, often associated with increased reserveation, which can be the pancargycinoma, commonly causedension and cysticillary artery 50. This转i
# Correct answer: C
# Model output: Answer: D. Oing from abdominal-line Lifeoccal荐
# Explanation: Intric acidia is commonly causes can cause inhibits's recentative suggest her fever indicate pneumonia, leading to hypers orTreeal arterous acuteœuvreing with gastrointest
# Correct answer: C
# Letter accuracy : 22.54%
# Avg explain PPL : 405.68

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cp -r mistral-1b-qa-qlora2/ /content/drive/MyDrive
